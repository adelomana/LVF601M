# %%
# Install qiime2 environemnt

# wget https://data.qiime2.org/distro/core/qiime2-2022.2-py38-linux-conda.yml
# conda env create -n qiime2_alo --file qiime2-2022.2-py38-linux-conda.yml
# conda activate qiime2_alo

# %%
# setup micom plugin

# wget https://raw.githubusercontent.com/micom-dev/q2-micom/master/q2-micom.yml
# conda env update -n qiime2_alo -f q2-micom.yml

# %%
# launch jupyter notebook

# %%
input_diet = 'Vegeterian.tsv'
output_diet = 'vegeterian.alo.qza'

# %%
input_diet = 'Meat.tsv'
output_diet = 'meat.alo.qza'

# %%
input_diet = 'Kimchi.tsv'
output_diet = 'kimchi.alo.qza'

# %%
input_diet = 'Cheese_mozzarella.tsv'
output_diet = 'cheese_mozzarella.alo.qza'

# %%
input_diet = 'Gluten_free.tsv'
output_diet = 'gluten_free.alo.qza'

# %%
input_diet = 'High_fiber.tsv'
output_diet = 'high_fiber.alo.qza'

# %%
input_diet = 'High_protein.tsv'
output_diet = 'high_protein.alo.qza'

# %%
input_diet = 'Plain_yogurt.tsv'
output_diet = 'plain_yogurt.alo.qza'

# %%
input_diet = 'Salad.tsv'
output_diet = 'salad.alo.qza'

# %%
import pandas as pd

medium = pd.read_csv(input_diet, index_col=False, sep="\t")
medium.columns = ["reaction", "flux"]
medium.reaction = medium.reaction.str.replace("(\[e\]$)|(\(e\)$)", "", regex=True)
medium.loc[medium.flux < 1e-4, "flux"] = 1e-4
medium.flux = medium.flux / 24
medium
# Out:
#       reaction         flux
# 0       EX_h2o  1016.498217
# 1    EX_ribflv     0.000079
# 2     EX_pydxn     0.000013
# 3       EX_fol     0.000004
# 4       EX_but     0.229629
# ..         ...          ...
# 63  EX_retinol     0.000020
# 64     EX_caro     0.000004
# 65   EX_avite1     0.000029
# 66    EX_vitd3     0.000004
# 67     EX_phyQ     0.000004
#
# [68 rows x 2 columns]

# %%
from cobra.io import read_sbml_model
import pandas as pd

recon3 = read_sbml_model("Recon3D.xml.gz")
exchanges = pd.Series([r.id for r in recon3.exchanges])
exchanges = exchanges.str.replace("__", "_").str.replace("_e$", "", regex=True)
exchanges.head()
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# 0     EX_5adtststerone
# 1    EX_5adtststerones
# 2             EX_5fthf
# 3             EX_5htrp
# 4             EX_5mthf
# dtype: object

# %%
medium["dilution"] = 1.0
medium.loc[medium.reaction.isin(exchanges), "dilution"] = 0.1
medium.dilution.value_counts()
# Out:
# 0.1    61
# 1.0     7
# Name: dilution, dtype: int64

# %%
medium["metabolite"] = medium.reaction.str.replace("^EX_", "", regex=True) + "_m"
medium["global_id"] = medium.reaction + "(e)"
medium["reaction"] = medium.reaction + "_m"
medium.loc[medium.flux < 1e-4, "flux"] = 1e-4
medium
# Out:
#         reaction         flux  dilution metabolite      global_id
# 0       EX_h2o_m  1016.498217       0.1      h2o_m      EX_h2o(e)
# 1    EX_ribflv_m     0.000100       0.1   ribflv_m   EX_ribflv(e)
# 2     EX_pydxn_m     0.000100       0.1    pydxn_m    EX_pydxn(e)
# 3       EX_fol_m     0.000100       0.1      fol_m      EX_fol(e)
# 4       EX_but_m     0.229629       0.1      but_m      EX_but(e)
# ..           ...          ...       ...        ...            ...
# 63  EX_retinol_m     0.000100       0.1  retinol_m  EX_retinol(e)
# 64     EX_caro_m     0.000100       0.1     caro_m     EX_caro(e)
# 65   EX_avite1_m     0.000100       0.1   avite1_m   EX_avite1(e)
# 66    EX_vitd3_m     0.000100       0.1    vitd3_m    EX_vitd3(e)
# 67     EX_phyQ_m     0.000100       1.0     phyQ_m     EX_phyQ(e)
#
# [68 rows x 5 columns]

# %%
from micom.workflows.db_media import check_db_medium

check = check_db_medium("agora103_genus.qza", medium, threads=20)
# Out:
# Output()
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
# ...

# %%
check.can_grow.value_counts()
# Out:
# False    227
# Name: can_grow, dtype: int64

# %%
from micom.workflows.db_media import complete_db_medium

manifest, imports = complete_db_medium("agora103_genus.qza", medium, growth=0.001, threads=20, max_added_import=10, weights="C")
# Out:
# Output()
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
# ...

# %%
manifest.can_grow.value_counts()
# Out:
# True    227
# Name: can_grow, dtype: int64

# %%
manifest.added.describe()
# Out:
# count    227.000000
# mean       9.704846
# std        4.373707
# min        3.000000
# 25%        6.000000
# 50%       10.000000
# 75%       12.000000
# max       26.000000
# Name: added, dtype: float64

# %%
fluxes = imports.max()
fluxes = fluxes[(fluxes > 1e-6) | fluxes.index.isin(medium.reaction)]
completed = pd.DataFrame({
    "reaction": fluxes.index,
    "metabolite": fluxes.index.str.replace("^EX_", "", regex=True),
    "global_id": fluxes.index.str.replace("_m$", "(e)", regex=True),
    "flux": fluxes
})
completed.shape
# Out:
# (135, 4)

# %%
completed
# Out:
#                 reaction metabolite     global_id      flux
# EX_4hbz_m      EX_4hbz_m     4hbz_m    EX_4hbz(e)  0.000008
# EX_ala_L_m    EX_ala_L_m    ala_L_m   EX_ala_L(e)  0.173040
# EX_arab_D_m  EX_arab_D_m   arab_D_m  EX_arab_D(e)  0.000075
# EX_arg_L_m    EX_arg_L_m    arg_L_m   EX_arg_L(e)  0.123662
# EX_asp_L_m    EX_asp_L_m    asp_L_m   EX_asp_L(e)  0.216858
# ...                  ...        ...           ...       ...
# EX_arab_L_m  EX_arab_L_m   arab_L_m  EX_arab_L(e)  0.000751
# EX_tre_m        EX_tre_m      tre_m     EX_tre(e)  0.000092
# EX_dgsn_m      EX_dgsn_m     dgsn_m    EX_dgsn(e)  0.000167
# EX_nmn_m        EX_nmn_m      nmn_m     EX_nmn(e)  0.000529
# EX_strch1_m  EX_strch1_m   strch1_m  EX_strch1(e)  0.000061
#
# [135 rows x 4 columns]

# %%
from qiime2 import Artifact

arti = Artifact.import_data("MicomMedium[Global]", completed)
arti.save(output_diet)
# Out:
# 'plain_yogurt.alo.qza'

# %%
# dealig with error
arti = Artifact.import_data("MicomMedium[Global]", completed)

# %%
check = check_db_medium("agora103_genus.qza", completed, threads=20)
check.can_grow.value_counts()
# Out:
# Output()
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Scaling...
# ...

# %%
check.growth_rate.describe()
# Out:
# count    227.000000
# mean       0.002187
# std        0.001469
# min        0.001000
# 25%        0.001000
# 50%        0.001803
# 75%        0.002564
# max        0.006467
# Name: growth_rate, dtype: float64
